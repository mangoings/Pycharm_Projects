# %%
# Series()로 생성한 데이터의 예
import pandas as pd

# %%
s1 = pd.Series([1,2,3,4,5])
s2 = pd.Series([10,20,30,40,50])

# %%
s2 /s1
# Out:
# 0    10.0
# 1    10.0
# 2    10.0
# 3    10.0
# 4    10.0
# dtype: float64

# %%
s3 =  pd.Series([1,2,3,4])
s4 = pd.Series([10,20,30,40,50])

# %%
s3 + s4
# Out:
# 0    11.0
# 1    22.0
# 2    33.0
# 3    44.0
# 4     NaN
# dtype: float64
