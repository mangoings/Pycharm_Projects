# %%
# daegufood_street.csv 파일을 읽어서 음식점이 많은 음식골목명을 순서대로 출력

# %%
import pandas as pd

# %%
df1 = pd.read_csv('./input/daegufood_street.csv')
df1
# Out:
#                음식골목명        음식점 상호                      음식점 주소
# 0    (동구)동촌유원지명물먹거리촌       (주)32마루     동구 효동로2길 33-7, 1층 (효목동)
# 1    (동구)동촌유원지명물먹거리촌  (주)삼십미리에스프레소    동구 효동로6길 47-5, 1~2층(효목동)
# 2    (동구)동촌유원지명물먹거리촌     365감자탕동촌점     동구 효동로2길 41, 1,2층 (효목동)
# 3    (동구)동촌유원지명물먹거리촌  55온족발 동촌유원지점       동구 효동로2길 45, 4층 (효목동)
# 4    (동구)동촌유원지명물먹거리촌            고고  동구 효동로2길 57-11, 지하1층 (효목동)
# ..               ...           ...                         ...
# 472       (동구)서촌먹거리촌      팔공닭구이닭울림          동구 팔공산로2길 79 (덕곡동)
# 473       (동구)서촌먹거리촌         더기네장어          동구 팔공산로2길 88 (덕곡동)
# 474       (동구)서촌먹거리촌       팔공산자락식당           동구 팔공산로9길 6 (덕곡동)
# 475       (동구)서촌먹거리촌          밥을짓다         동구 팔공산로9길 6-1 (덕곡동)
# 476       (동구)서촌먹거리촌          전원식당         동구 팔공산로9길 8-1 (덕곡동)
#
# [477 rows x 3 columns]

# %%
df1.info()
df1['음식골목명'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 477 entries, 0 to 476
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   음식골목명   477 non-null    object
#  1   음식점 상호  477 non-null    object
#  2   음식점 주소  477 non-null    object
# dtypes: object(3)
# memory usage: 11.3+ KB
# 음식골목명
# (동구)동대구역터미널 먹거리골목    110
# (동구)서촌먹거리촌           107
# (동구)동촌유원지명물먹거리촌       83
# (동구)혁신도시 중앙상가연합회      62
# (동구)동화사먹거리촌           37
# (동구)동막골               28
# (동구)평화시장닭똥집골목         21
# (동구)갓바위먹거리촌           18
# (동구)파계사먹거리촌           11
# Name: count, dtype: int64

# %%
df1.value_counts(['음식골목명'])
# Out:
# 음식골목명
# (동구)동대구역터미널 먹거리골목    110
# (동구)서촌먹거리촌           107
# (동구)동촌유원지명물먹거리촌       83
# (동구)혁신도시 중앙상가연합회      62
# (동구)동화사먹거리촌           37
# (동구)동막골               28
# (동구)평화시장닭똥집골목         21
# (동구)갓바위먹거리촌           18
# (동구)파계사먹거리촌           11
# Name: count, dtype: int64

# %%
df2 = df1.value_counts(['음식골목명'])
df2
# Out:
# 음식골목명
# (동구)동대구역터미널 먹거리골목    110
# (동구)서촌먹거리촌           107
# (동구)동촌유원지명물먹거리촌       83
# (동구)혁신도시 중앙상가연합회      62
# (동구)동화사먹거리촌           37
# (동구)동막골               28
# (동구)평화시장닭똥집골목         21
# (동구)갓바위먹거리촌           18
# (동구)파계사먹거리촌           11
# Name: count, dtype: int64

# %%
df2.to_csv('./output/daegufood_street_summary.csv')
