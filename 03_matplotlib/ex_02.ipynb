# %%
# 다음은 어떤 시리얼에 포함된 비타민의 함량을 나타낸 데이터입니다.
# 각 항목의 비율이 나타날 수 있도록 그래프로 표시하세요.
#
# 종류 : 함량
# 비타민 A : 0.18
# 비타민 B1 : 0.3
# 비타민 B2 : 3.33
# 나이아신 : 3.75
# 비타민 B6 : 0.38
# 비타민 C : 25
# 비타민 D : 0.25
# 비타민 E : 2.75
# 엽산 : 0.1

# %%
import matplotlib.pyplot as plt
import matplotlib

# %%
matplotlib.rcParams['font.family'] = 'batang'
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
data = [0.18, 0.3, 3.33, 3.75, 0.38, 25, 0.25, 2.75, 0.1]
vitamin = ['비타민A', '비타민B1', '비타민B2', '나이아신', '비타민B6', '비타민C', '비타민D', '비타민E', '엽산']

# %%
plt.figure(figsize=(8, 8))
plt.pie(data, labels=vitamin, autopct='%1.1f%%')
plt.title('시리얼에 포함된 비타민의 비율')
plt.legend(data)
plt.show()

# %%
# 판다스 이용
import pandas as pd

# %%
df = pd.Series(data)
df.index = vitamin
df
# Out:
# 비타민A      0.18
# 비타민B1     0.30
# 비타민B2     3.33
# 나이아신      3.75
# 비타민B6     0.38
# 비타민C     25.00
# 비타민D      0.25
# 비타민E      2.75
# 엽산        0.10
# dtype: float64

# %%
plt.figure(figsize=(8, 8))
plt.pie(df, labels=df.index, autopct='%1.1f%%')
plt.title('시리얼에 포함된 비타민의 비율')
plt.legend(df)
plt.show()
