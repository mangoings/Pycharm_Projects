# %%
# STREAMlit 설치 밒 실행

# %%
# 1. 테스트 파일 작성

# streamlit 실행 파일은 확장자가 py인 파이썬 파일이어야 함. 주피터 노트북으로 작업된 파일은 안됨
# main.py 파일 생성 후 코딩

# %%
# print(df)가 아니라 df만 코딩

# %%
# terminal에서 streamlit run main.py 실행

# %%
# 웹페이지가 자동으로 생성됨
