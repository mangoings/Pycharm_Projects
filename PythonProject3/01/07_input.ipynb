# %%
# 사용자가 입력한 값을 변수로 받아올 수 있음
# 대표적으로 한 줄의 문자열 값을 받아올 수 있는 text_input과
# 수치형 값을 받아올 수 있는 number_input,
# 날짜 및 시간 형식을 받아올 수 있는 data_input, time_input 함수가 있음
#
# text_input 함수로 값을 받은 후에 파이썬 스크립트로 다른 형식으로 변환할 수도 있으므로,
# 모든 함수를 자세히 익힐 필요는 없음

# %%
from email.policy import default

import streamlit as st

# text input
string = st.text_input(
    'Movie title',
    placeholder='Write down the title of your favourite movie',
    max_chars=32
)
if string:
    st.write(f'Your answer is {string}')

# %%
# text_input는 여러가지 인자를 사용
# max_chars 인자는 입력되는 값의 최대 길이를 제한
# placeholder는 아무 값도 입력되지 않았을 때 위젯에 보여지는 문구

# %%
# password 인자 활용
string = st.text_input(
    'Movie title',
    placeholder='Write down the title of your favourite movie',
    type='password'
)

if string:
    st.write(f'Your answer is {string}')

# %%
# type 인자에 password를 전달하게 되면 암호 입력 모드를 활성화하여 위젯에 입력되고 있는 값이 암호화되어 나타나게 설정할 수 있음
# 기본값은 default
# 받아온 입력값을 다시 텍스트 형식으로 출력했을 때에는 암호화된 형식이 아니라
# 사용자가 입력한 값이 그대로 출력
