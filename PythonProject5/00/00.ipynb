# %%
# !pip install scikit-learn==1.6.1
# Out:
# Collecting scikit-learn==1.6.1
#   Using cached scikit_learn-1.6.1-cp310-cp310-win_amd64.whl.metadata (15 kB)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from scikit-learn==1.6.1) (2.2.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from scikit-learn==1.6.1) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from scikit-learn==1.6.1) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from scikit-learn==1.6.1) (3.6.0)
# Using cached scikit_learn-1.6.1-cp310-cp310-win_amd64.whl (11.1 MB)
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.3.0
#     Uninstalling scikit-learn-1.3.0:
#       Successfully uninstalled scikit-learn-1.3.0
# Successfully installed scikit-learn-1.6.1
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\kui45\anaconda3\envs\PythonProject5\Lib\site-packages\~-learn'.
#   You can safely remove it manually.

# %%
# !pip uninstall scikit-learn numpy
# Out:
# ^C

# %%
import sklearn
sklearn.__version__
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 import sklearn
#       2 sklearn.__version__
#
# File ~\anaconda3\envs\PythonProject5\lib\site-packages\sklearn\__init__.py:73
#      67 if __SKLEARN_SETUP__:
#      68     sys.stderr.write("Partial import of sklearn during the build process.\n")
#      69     # We are not importing the rest of scikit-learn during the build
#      70     # process, as it may not be compiled yet
#      71 else:
#      72     # `_distributor_init` allows distributors to run custom init code.
# ---> 73     # For instance, for the Windows wheel, this is used to pre-load the
#      74     # vcomp shared library runtime for OpenMP embedded in the sklearn/.libs
#      75     # sub-folder.
#      76     # It is necessary to do this prior to importing show_versions as the
#      77     # later is linked to the OpenMP runtime to make it possible to introspect
#      78     # it and importing it first would fail if the OpenMP dll cannot be found.
#      79     from . import (
#      80         __check_build,  # noqa: F401
#      81         _distributor_init,  # noqa: F401
#      82     )
#      83     from .base import clone
#
# File ~\anaconda3\envs\PythonProject5\lib\site-packages\sklearn\base.py:19
#      17 from ._config import config_context, get_config
#      18 from .exceptions import InconsistentVersionWarning
# ---> 19 from .utils import _IS_32BIT
#      20 from .utils._estimator_html_repr import estimator_html_repr
#      21 from .utils._metadata_requests import _MetadataRequester
#
# ImportError: cannot import name '_HTMLDocumentationLinkMixin' from 'sklearn.utils._estimator_html_repr' (C:\Users\kui45\anaconda3\envs\PythonProject5\lib\site-packages\sklearn\utils\_estimator_html_repr.py)

# %%
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (2.2.4)

# %%
# !pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-2.2.3-cp310-cp310-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from pandas) (2.2.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2025.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2025.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading pandas-2.2.3-cp310-cp310-win_amd64.whl (11.6 MB)
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    ------------------------- -------------- 7.3/11.6 MB 41.4 MB/s eta 0:00:01
#    ---------------------------------------- 11.6/11.6 MB 40.3 MB/s eta 0:00:00
# Using cached pytz-2025.1-py2.py3-none-any.whl (507 kB)
# Using cached tzdata-2025.1-py2.py3-none-any.whl (346 kB)
# Installing collected packages: pytz, tzdata, pandas
# Successfully installed pandas-2.2.3 pytz-2025.1 tzdata-2025.1

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.10.1-cp310-cp310-win_amd64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.1-cp310-cp310-win_amd64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.56.0-cp310-cp310-win_amd64.whl.metadata (103 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.8-cp310-cp310-win_amd64.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.23 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from matplotlib) (2.2.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from matplotlib) (24.2)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-11.1.0-cp310-cp310-win_amd64.whl.metadata (9.3 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Using cached pyparsing-3.2.1-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading matplotlib-3.10.1-cp310-cp310-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    -------------------------------- ------- 6.6/8.1 MB 36.6 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 33.2 MB/s eta 0:00:00
# Downloading contourpy-1.3.1-cp310-cp310-win_amd64.whl (218 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.56.0-cp310-cp310-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 2.2/2.2 MB 31.3 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.8-cp310-cp310-win_amd64.whl (71 kB)
# Downloading pillow-11.1.0-cp310-cp310-win_amd64.whl (2.6 MB)
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ---------------------------------------- 2.6/2.6 MB 37.5 MB/s eta 0:00:00
# Using cached pyparsing-3.2.1-py3-none-any.whl (107 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.1 cycler-0.12.1 fonttools-4.56.0 kiwisolver-1.4.8 matplotlib-3.10.1 pillow-11.1.0 pyparsing-3.2.1

# %%
# !pip install seaborn
# Out:
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from seaborn) (2.2.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from seaborn) (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: six>=1.5 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2

# %%
import seaborn as sns
sns.__version__
# Out:
# '0.13.2'

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.10.1'

# %%
import numpy as np
np.__version__
# Out:
# '2.2.4'

# %%
import pandas as pd
pd.__version__
# Out:
# '2.2.3'

# %%
# !pip install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-3.0.0-py3-none-win_amd64.whl.metadata (2.1 kB)
# Requirement already satisfied: numpy in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from xgboost) (2.2.4)
# Requirement already satisfied: scipy in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from xgboost) (1.15.2)
# Downloading xgboost-3.0.0-py3-none-win_amd64.whl (150.0 MB)
#    ---------------------------------------- 0.0/150.0 MB ? eta -:--:--
#    -- ------------------------------------- 7.9/150.0 MB 48.4 MB/s eta 0:00:03
#    ----- ---------------------------------- 18.9/150.0 MB 47.6 MB/s eta 0:00:03
#    ------- -------------------------------- 29.4/150.0 MB 49.0 MB/s eta 0:00:03
#    ---------- ----------------------------- 39.1/150.0 MB 48.7 MB/s eta 0:00:03
#    ------------ --------------------------- 47.7/150.0 MB 47.4 MB/s eta 0:00:03
#    --------------- ------------------------ 58.2/150.0 MB 47.5 MB/s eta 0:00:02
#    ----------------- ---------------------- 66.6/150.0 MB 46.6 MB/s eta 0:00:02
#    -------------------- ------------------- 76.5/150.0 MB 46.9 MB/s eta 0:00:02
#    ----------------------- ---------------- 86.5/150.0 MB 47.2 MB/s eta 0:00:02
#    ------------------------- -------------- 96.5/150.0 MB 47.0 MB/s eta 0:00:02
#    --------------------------- ----------- 105.9/150.0 MB 47.0 MB/s eta 0:00:01
#    ------------------------------ -------- 115.6/150.0 MB 47.0 MB/s eta 0:00:01
#    -------------------------------- ------ 125.6/150.0 MB 47.2 MB/s eta 0:00:01
#    ----------------------------------- --- 134.7/150.0 MB 47.0 MB/s eta 0:00:01
#    ------------------------------------- - 145.0/150.0 MB 47.2 MB/s eta 0:00:01
#    --------------------------------------  149.9/150.0 MB 47.0 MB/s eta 0:00:01
#    --------------------------------------- 150.0/150.0 MB 44.1 MB/s eta 0:00:00
# Installing collected packages: xgboost
# Successfully installed xgboost-3.0.0

# %%
import xgboost
xgboost.__version__
# Out:
# '3.0.0'

# %%
# !pip install pydotplus
# Out:
# Collecting pydotplus
#   Downloading pydotplus-2.0.2.tar.gz (278 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: pyparsing>=2.0.1 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from pydotplus) (3.2.1)
# Building wheels for collected packages: pydotplus
#   Building wheel for pydotplus (setup.py): started
#   Building wheel for pydotplus (setup.py): finished with status 'done'
#   Created wheel for pydotplus: filename=pydotplus-2.0.2-py3-none-any.whl size=24626 sha256=e61e440cca5bf3ac986b2bd5d3be054ab5a97683065314994314a19cde20a7bc
#   Stored in directory: c:\users\kui45\appdata\local\pip\cache\wheels\69\b2\67\08f0eef649af92df772c09f451558298e07fab1bc7cdf33db0
# Successfully built pydotplus
# Installing collected packages: pydotplus
# Successfully installed pydotplus-2.0.2

# %%
# !pip install openpyxl
# Out:
# Collecting openpyxl
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Using cached et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Using cached et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5

# %%
# !pip install mlxtend
# Out:
# Collecting mlxtend
#   Downloading mlxtend-0.23.4-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from mlxtend) (1.15.2)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from mlxtend) (2.2.4)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from mlxtend) (2.2.3)
# Requirement already satisfied: scikit-learn>=1.3.1 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from mlxtend) (1.6.1)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from mlxtend) (3.10.1)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from mlxtend) (1.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from pandas>=0.24.2->mlxtend) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from pandas>=0.24.2->mlxtend) (2025.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from scikit-learn>=1.3.1->mlxtend) (3.6.0)
# Requirement already satisfied: six>=1.5 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)
# Downloading mlxtend-0.23.4-py3-none-any.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 1.4/1.4 MB 34.1 MB/s eta 0:00:00
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.23.4

# %%
# !pip install networkx
# Out:
# Collecting networkx
#   Downloading networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 1.7/1.7 MB 31.1 MB/s eta 0:00:00
# Installing collected packages: networkx
# Successfully installed networkx-3.4.2

# %%
# !pip install prophet
# Out:
# Collecting prophet
#   Downloading prophet-1.1.6-py3-none-win_amd64.whl.metadata (3.6 kB)
# Collecting cmdstanpy>=1.0.4 (from prophet)
#   Downloading cmdstanpy-1.2.5-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: numpy>=1.15.4 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from prophet) (2.2.4)
# Requirement already satisfied: matplotlib>=2.0.0 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from prophet) (3.10.1)
# Requirement already satisfied: pandas>=1.0.4 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from prophet) (2.2.3)
# Collecting holidays<1,>=0.25 (from prophet)
#   Downloading holidays-0.69-py3-none-any.whl.metadata (28 kB)
# Collecting tqdm>=4.36.1 (from prophet)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting importlib-resources (from prophet)
#   Downloading importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Collecting stanio<2.0.0,>=0.4.0 (from cmdstanpy>=1.0.4->prophet)
#   Downloading stanio-0.5.1-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: python-dateutil in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from holidays<1,>=0.25->prophet) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from matplotlib>=2.0.0->prophet) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from matplotlib>=2.0.0->prophet) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from matplotlib>=2.0.0->prophet) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from matplotlib>=2.0.0->prophet) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from matplotlib>=2.0.0->prophet) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from matplotlib>=2.0.0->prophet) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from matplotlib>=2.0.0->prophet) (3.2.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from pandas>=1.0.4->prophet) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from pandas>=1.0.4->prophet) (2025.1)
# Requirement already satisfied: colorama in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from tqdm>=4.36.1->prophet) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from python-dateutil->holidays<1,>=0.25->prophet) (1.16.0)
# Downloading prophet-1.1.6-py3-none-win_amd64.whl (13.3 MB)
#    ---------------------------------------- 0.0/13.3 MB ? eta -:--:--
#    ----------- ---------------------------- 3.9/13.3 MB 19.5 MB/s eta 0:00:01
#    ---------------------------------------  13.1/13.3 MB 31.6 MB/s eta 0:00:01
#    ---------------------------------------- 13.3/13.3 MB 29.8 MB/s eta 0:00:00
# Downloading cmdstanpy-1.2.5-py3-none-any.whl (94 kB)
# Downloading holidays-0.69-py3-none-any.whl (863 kB)
#    ---------------------------------------- 0.0/863.9 kB ? eta -:--:--
#    --------------------------------------- 863.9/863.9 kB 40.1 MB/s eta 0:00:00
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Downloading stanio-0.5.1-py3-none-any.whl (8.1 kB)
# Installing collected packages: tqdm, stanio, importlib-resources, holidays, cmdstanpy, prophet
# Successfully installed cmdstanpy-1.2.5 holidays-0.69 importlib-resources-6.5.2 prophet-1.1.6 stanio-0.5.1 tqdm-4.67.1

# %%
# !pip install plotly
# Out:
# Collecting plotly
#   Downloading plotly-6.0.1-py3-none-any.whl.metadata (6.7 kB)
# Collecting narwhals>=1.15.1 (from plotly)
#   Downloading narwhals-1.31.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from plotly) (24.2)
# Downloading plotly-6.0.1-py3-none-any.whl (14.8 MB)
#    ---------------------------------------- 0.0/14.8 MB ? eta -:--:--
#    ---------------------- ----------------- 8.4/14.8 MB 47.2 MB/s eta 0:00:01
#    ---------------------------------------- 14.8/14.8 MB 40.5 MB/s eta 0:00:00
# Downloading narwhals-1.31.0-py3-none-any.whl (313 kB)
# Installing collected packages: narwhals, plotly
# Successfully installed narwhals-1.31.0 plotly-6.0.1

# %%
# !pip install graphviz
# Out:
# Collecting graphviz
#   Downloading graphviz-0.20.3-py3-none-any.whl.metadata (12 kB)
# Downloading graphviz-0.20.3-py3-none-any.whl (47 kB)
# Installing collected packages: graphviz
# Successfully installed graphviz-0.20.3

# %%
# !pip install prophet
# Out:
# Requirement already satisfied: prophet in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (1.1.6)
# Requirement already satisfied: cmdstanpy>=1.0.4 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from prophet) (1.2.5)
# Requirement already satisfied: numpy>=1.15.4 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from prophet) (2.2.4)
# Requirement already satisfied: matplotlib>=2.0.0 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from prophet) (3.10.1)
# Requirement already satisfied: pandas>=1.0.4 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from prophet) (2.2.3)
# Requirement already satisfied: holidays<1,>=0.25 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from prophet) (0.69)
# Requirement already satisfied: tqdm>=4.36.1 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from prophet) (4.67.1)
# Requirement already satisfied: importlib-resources in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from prophet) (6.5.2)
# Requirement already satisfied: stanio<2.0.0,>=0.4.0 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from cmdstanpy>=1.0.4->prophet) (0.5.1)
# Requirement already satisfied: python-dateutil in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from holidays<1,>=0.25->prophet) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from matplotlib>=2.0.0->prophet) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from matplotlib>=2.0.0->prophet) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from matplotlib>=2.0.0->prophet) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from matplotlib>=2.0.0->prophet) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from matplotlib>=2.0.0->prophet) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from matplotlib>=2.0.0->prophet) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from matplotlib>=2.0.0->prophet) (3.2.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from pandas>=1.0.4->prophet) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from pandas>=1.0.4->prophet) (2025.1)
# Requirement already satisfied: colorama in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from tqdm>=4.36.1->prophet) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from python-dateutil->holidays<1,>=0.25->prophet) (1.16.0)

# %%
# !pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (6.0.1)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from plotly) (1.31.0)
# Requirement already satisfied: packaging in c:\users\kui45\anaconda3\envs\pythonproject5\lib\site-packages (from plotly) (24.2)
