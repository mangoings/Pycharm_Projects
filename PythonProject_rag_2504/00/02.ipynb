# %%
### 필수 라이브러리 설치

# %%
# openai
# !pip install openai

# %%
# %pip install --upgrade pip
# %pip install --upgrade distlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import openai
openai.__version__
# Out:
# '1.76.2'

# %%
# langchain
# !pip install langchain

# %%
import langchain
langchain.__version__
# Out:
# '0.3.24'

# %%
# !pip install langchain-community langchain-experimental langchain-core langchain-openai langsmith
# Out:
# ...
#   Using cached langchain_community-0.3.23-py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached langchain_experimental-0.3.4-py3-none-any.whl.metadata (1.7 kB)
# ...
#   Using cached langchain_openai-0.3.14-py3-none-any.whl.metadata (2.3 kB)
# ...
#   Using cached aiohttp-3.11.18-cp310-cp310-win_amd64.whl.metadata (8.0 kB)
# ...
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# ...
#   Using cached pydantic_settings-2.9.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached httpx_sse-0.4.0-py3-none-any.whl.metadata (9.0 kB)
# ...
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# ...
#   Using cached aiosignal-1.3.2-py2.py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached frozenlist-1.6.0-cp310-cp310-win_amd64.whl.metadata (16 kB)
# ...
#   Using cached multidict-6.4.3-cp310-cp310-win_amd64.whl.metadata (5.5 kB)
# ...
#   Using cached yarl-1.20.0-cp310-cp310-win_amd64.whl.metadata (74 kB)
# ...
#   Using cached marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# ...

# %%
# !pip install langchain_huggingface
# Out:
# ...
#   Using cached fsspec-2025.3.2-py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached scikit_learn-1.6.1-cp310-cp310-win_amd64.whl.metadata (15 kB)
# ...
#   Using cached scipy-1.15.2-cp310-cp310-win_amd64.whl.metadata (60 kB)
# ...
#   Using cached pillow-11.2.1-cp310-cp310-win_amd64.whl.metadata (9.1 kB)
# ...
#   Using cached networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# ...
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# ...
# Using cached fsspec-2025.3.2-py3-none-any.whl (194 kB)
# ...
#    ---------------------------------------- 0.0/10.4 MB ? eta -:--:--
#    ---------- ----------------------------- 2.6/10.4 MB 12.6 MB/s eta 0:00:01
#    ----------------------- ---------------- 6.0/10.4 MB 14.8 MB/s eta 0:00:01
#    ---------------------------------------- 10.4/10.4 MB 17.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
# ...

# %%
# huggingface-hub
# !pip install huggingface-hub

# %%
import huggingface_hub
huggingface_hub.__version__
# Out:
# '0.30.2'

# %%
# streamlit
# !pip install streamlit
# Out:
# ...
#   Using cached altair-5.5.0-py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# ...
#   Using cached cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# ...
#   Using cached pandas-2.2.3-cp310-cp310-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# ...
#   Using cached watchdog-6.0.0-py3-none-win_amd64.whl.metadata (44 kB)
# ...
#   Using cached GitPython-3.1.44-py3-none-any.whl.metadata (13 kB)
# ...
#   Using cached pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# ...
#   Using cached narwhals-1.37.1-py3-none-any.whl.metadata (9.3 kB)
# ...
#   Using cached gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# ...
#   Using cached smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...

# %%
# !pip install matplotlib
# Out:
# ...
#   Using cached matplotlib-3.10.1-cp310-cp310-win_amd64.whl.metadata (11 kB)
# ...
#   Using cached contourpy-1.3.2-cp310-cp310-win_amd64.whl.metadata (5.5 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached fonttools-4.57.0-cp310-cp310-win_amd64.whl.metadata (104 kB)
# ...
#   Using cached kiwisolver-1.4.8-cp310-cp310-win_amd64.whl.metadata (6.3 kB)
# ...
#   Using cached pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# ...
# Using cached matplotlib-3.10.1-cp310-cp310-win_amd64.whl (8.1 MB)
# Using cached contourpy-1.3.2-cp310-cp310-win_amd64.whl (221 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.57.0-cp310-cp310-win_amd64.whl (2.2 MB)
# Using cached kiwisolver-1.4.8-cp310-cp310-win_amd64.whl (71 kB)
# Using cached pyparsing-3.2.3-py3-none-any.whl (111 kB)
# ...
#
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
# ...

# %%
# !pip install pypdf

# %%
# !pip install tiktoken

# %%
# !pip install faiss-cpu
# Out:
# ...
#    ---------------------------------------- 0.0/15.0 MB ? eta -:--:--
#    ----------- ---------------------------- 4.2/15.0 MB 22.9 MB/s eta 0:00:01
#    ----------------------- ---------------- 8.9/15.0 MB 23.1 MB/s eta 0:00:01
#    ------------------------------------ --- 13.6/15.0 MB 22.5 MB/s eta 0:00:01
#    ---------------------------------------- 15.0/15.0 MB 21.9 MB/s eta 0:00:00
# ...

# %%
# !pip install sentence-transformers

# %%
# !pip install wikipedia
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for wikipedia: filename=wikipedia-1.4.0-py3-none-any.whl size=11785 sha256=7abf7b32ad48ebdb62f9e90f0217e16e6dcb73c464f1573e1b6892a0bf101b3e
#   Stored in directory: c:\users\kui45\appdata\local\pip\cache\wheels\5e\b6\c5\93f3dec388ae76edc830cb42901bb0232504dfc0df02fc50de
# Successfully built wikipedia
# ...
#   DEPRECATION: Building 'wikipedia' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'wikipedia'. Discussion can be found at https://github.com/pypa/pip/issues/6334

# %%
# !pip install numexpr

# %%
# !pip install PyPDF2

# %%
# !pip install streamlit-chat
# Out:
# ...
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 1.2/1.2 MB 6.1 MB/s eta 0:00:00
# ...

# %%
# !pip install gensim
# Out:
# ...
#   Using cached numpy-1.26.4-cp310-cp310-win_amd64.whl.metadata (61 kB)
# ...
#   Using cached wrapt-1.17.2-cp310-cp310-win_amd64.whl.metadata (6.5 kB)
# ...
#    ---------------------------------------- 0.0/24.0 MB ? eta -:--:--
#    ------ --------------------------------- 3.9/24.0 MB 21.5 MB/s eta 0:00:01
#    ------------- -------------------------- 8.4/24.0 MB 21.7 MB/s eta 0:00:01
#    --------------------- ------------------ 12.8/24.0 MB 21.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 17.8/24.0 MB 22.1 MB/s eta 0:00:01
#    ------------------------------------- -- 22.5/24.0 MB 22.3 MB/s eta 0:00:01
#    ---------------------------------------- 24.0/24.0 MB 20.8 MB/s eta 0:00:00
# Using cached numpy-1.26.4-cp310-cp310-win_amd64.whl (15.8 MB)
# ...
#    ---------------------------------------- 0.0/46.2 MB ? eta -:--:--
#    ---- ----------------------------------- 5.2/46.2 MB 22.7 MB/s eta 0:00:02
#    -------- ------------------------------- 10.0/46.2 MB 23.9 MB/s eta 0:00:02
# ...

# %%
# !pip install unstructured
# Out:
# ...
#      ---------------------------------------- 0.0/981.5 kB ? eta -:--:--
#      ------------------------------------- 981.5/981.5 kB 11.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----------------------------- ---------- 1.3/1.8 MB 8.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 5.7 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/590.6 kB ? eta -:--:--
#    ---------------------------------------- 590.6/590.6 kB 7.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    -------------------------------------- - 3.7/3.8 MB 18.2 MB/s eta 0:00:01
#    ---------------------------------------- 3.8/3.8 MB 16.3 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
# ...

# %%
# !pip install sentence-transformers
# Out:
# ...
# [notice] A new release of pip is available: 25.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install chromadb
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Using cached importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# ...
#   Using cached grpcio-1.71.0-cp310-cp310-win_amd64.whl.metadata (4.0 kB)
# ...
#   Using cached rich-14.0.0-py3-none-any.whl.metadata (18 kB)
# ...
#   Using cached flatbuffers-25.2.10-py2.py3-none-any.whl.metadata (875 bytes)
# ...
#   Using cached zipp-3.21.0-py3-none-any.whl.metadata (3.7 kB)
# ...
#   Using cached protobuf-5.29.4-cp310-abi3-win_amd64.whl.metadata (592 bytes)
# ...
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# ...
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# ...
#    ---------------------------------------- 0.0/18.8 MB ? eta -:--:--
# ...

# %%
# !pip install PyPDF2
# Out:
# ...
# [notice] A new release of pip is available: 25.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install --upgrade pip
# Out:
# ...
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 1.8/1.8 MB 24.8 MB/s eta 0:00:00
# [notice] A new release of pip is available: 25.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: To modify pip, please run the following command:
# C:\Users\kui45\anaconda3\envs\PythonProject_rag_2504\python.exe -m pip install --upgrade pip

# %%
# !C:\Users\kui45\anaconda3\envs\PythonProject_rag_2504\python.exe -m pip install --upgrade pip
# Out:
# ...
#   Using cached pip-25.1.1-py3-none-any.whl.metadata (3.6 kB)
# Using cached pip-25.1.1-py3-none-any.whl (1.8 MB)
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 25.1
#     Uninstalling pip-25.1:
#       Successfully uninstalled pip-25.1
# ...

# %%
# !pip install faiss-cpu

# %%
# !pip install streamlit-chat
