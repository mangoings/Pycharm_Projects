# %%
# .env 파일을 읽어서 환경변수로 설정
from dotenv import load_dotenv

# 토근 정보로드
load_dotenv()
# Out:
# True

# %%
from openai import OpenAI
client = OpenAI()

response = client.chat.completions.create(
    # chat: 채팅 관련 기능, completions: 채팅 답변을 만드는 기능, create: 만든 답변을 생성해 호출하는 기능
    model='gpt-3.5-turbo',
    messages=[
        {'role': 'user', 'content': 'python에 대해 알려주세요.'}
    ]
)
print(response.choices[0].message.content)
# Out:
# Python은 간결하고 쉽게 읽히는 문법을 가진 고수준 프로그래밍 언어입니다. 파이썬은 범용 프로그래밍 언어로 다양한 분야에서 사용되며, 머신 러닝, 인공지능, 웹 개발, 데이터 분석 등의 영역에서 널리 사용되고 있습니다.
#
# 파이썬은 인터프리터 언어로 바로 코드를 실행할 수 있어 번역 과정이 필요하지 않습니다. 또한 동적 타이핑을 지원하여 변수의 데이터 타입을 미리 선언할 필요가 없어 코드 작성이 간편합니다.
#
# 파이썬은 다양한 라이브러리와 도구들이 풍부하고 활발하게 유지보수되어 사용자들이 다양한 영역에서 쉽게 활용할 수 있습니다. 또한 다양한 운영 체제(Windows, macOS, Linux)에서 지원되어 개발 환경에 제한이 없습니다.
#
# 초보자부터 전문가까지 다양한 사용자 층에게 적합한 언어이며, 학습 곡선이 다른 언어보다 낮아 쉽게 배울 수 있습니다.
