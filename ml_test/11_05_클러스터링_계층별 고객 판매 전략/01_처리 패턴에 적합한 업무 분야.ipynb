# %%
### 01_처리 패턴에 적합한 업무 분야

# %%
### 1. 클러스터링

# %%
# 클러스터링은 마케팅에서 자주 쓰이는 기법
# '연관 분석'은 '전체 고객을 하나의 그룹'으로 봤을 때 상품 간의 연관성을 찾아내는 기법
# '협업 필터링'은 이와는 다르게 '개인'별로 영업전략을 달리하는 방식

# '클러스터링'은 연관 분석과 협업 필터링의 중간에 해당하는 기법
# 수학적인 방법으로 고객을 그룹으로 분류
# 모델이 그룹을 분류한 이유는 분석자가 결과를 보고 알아내야 하지만, 이유를 제대로 알아낸다면 각 그룹의 특성에 맞는 영업 전략을 짤 수 있음
# 고객을 하나의 대상으로 뭉뜰그리지는 않지만, 그렇다고 개인별로 전략을 구사할 정도로 세세하지 못하니 비교적 적당한 규모의 고객층에 대한 전략을
# 도찰할 수 있음

# %%
# 예를 들어 실습에서 식료품점의 고객을 분석하는데, 신선식품을 대량으로 구매하는 그룹이 있다는 것을 알 수 있음
# 그 결과에 따라 해당 그룹을 대상으로 '신선식품 특판 일을 늘이는'등의 전략을 구사할 수 있음

# %%
### 2. 차원 축소

# %%
# 수십, 수백 차원에 이르는 필드 수가 아주 많은 데이터를 적은 차원으로 압축하는 수학적 기법
# 데이터 행렬의 행(레코드)의 유사도에 근거해 그룹을 분리하는 것이 클러스터링이라면,
# 열(필드)을 그 유사도에 따라 집약하는 기법이 차원축소

# 특정 표본(예를 들어 어떤 개인의 고객 데이터)이 전체에서 어디쯤 위치하는가를 알아볼 때 자주 사용
# 가장 흔한 사례는 3차원 혹은 2차원으로 차원을 축소한 뒤 그 결과를 산점도로 나타내는 것
# 이 기법으로 고객을 분석하면 특별하게 중요한 고객을 발견할 수 있음

# %%
### 3. 클러스터링과 차원축소

# %%
# 클러스터링은 차원축소와 조합해서 사용하는 경우가 많음
# 반대로 차원축소를 먼저 적용해 대상을 분석하기 쉽게 한 다음, 클러스터링을 적용하는 사례도 있음

# %%
# 고객을 대상으로 한 앙케이트를 분석하는데도 클러스터링과 차원축소의 조합이 유용
# 먼저 '실내 취향 vs 아웃도어 취향', '안정 지향 vs 모험 지향'등과 같이
# 고객 분석 기준이 될 수 있는 두 축이 되는 고객의 취향에 대한 가설을 세움

# 이 가설을 기초해 앙케이트 항목을 여러 개 만든 후, 그 다음 차원축소의 결과로 나온 축도 이 가설 축을 바탕으로 함
# 그리고 각 고객의 앙케이트 결과에 차원축소를 적용해 어이쯤 위치하는지 판단한 후 고객 계층별 판매 프로모션 전략을 짬
# 이를테면 '아웃도어 취향이자 모험 지향에 맞는 상품 추천'
