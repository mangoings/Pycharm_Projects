# %%
### 02_예제 데이터 설명 및 유스케이스

# %%
# UCI 데이터 집합 중 하나인 'Wholesale customers Data set' (도매 고객 데이터 집합)을 사용.

# https://archive.ics.uci.edu/dataset/292/wholesale+customers

# 구체적인 데이터 필드는 다음과 같음.
# 판매 채널과 지역 이외의 필드는 해당 고객의 품목별 연간 지출액.
# 모두 합해 440건의 고객 데이터로 구성.

# Channel : 판매 채널. '호텔/레스토랑/카페/소매점'의 값을 가짐.
# Region : 지역. '리스본/포르투/기타'의 값을 가짐.
# Fresh : 신선식품.
# Milk : 유제품.
# Grocery : 식료품.
# Frozen : 냉동식품.
# Detergents_Paper : 세제 및 종이제품.
# Delicassen : 부식.
