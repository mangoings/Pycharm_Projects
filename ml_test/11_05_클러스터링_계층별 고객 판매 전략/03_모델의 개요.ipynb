# %%
### 03_모델의 개요

# %%
### 1. 클러스터링

# %%
# 클러스터링은 그룹을 나누는 처리 패턴
# 지도학습이 분류와 비지도학습의 클러스터링의 차이점은 정답 데이터의 유무
# 분류는 정답을 아는 상태에서 학습을 진행하며, 클러스터링은 정답 없이 학습이 진행

# %%
# 정답이 없다는 말에서 쉽게 상상할 수 있듯이 분류보다는 클러스터링이 더 어려운 문제이며,
# 정답이 없는 만큼 분류처럼 정확도를 특정하는 것도 애초에 불가능
# 그런데도 마케팅 등 클러스터링이 유용한 분야가 많아서 자주 사용되는 처리 패턴

# 분류와 마찬가지로 클러스터링도 여러 알고리즘이 있음

# %%
### 2. 차원 축소

# %%
# 머신러닝 모델의 입력 데이터는 적게는 수십에서 수백 개에 이르는 필드로 구성됨
# 이렇게 데이터의 차원이 너무 높으면 데이터의 상태를 판단하기가 어려움
# 이런 데이터의 주요 부분을 2차원이나 3차원으로 축소한다면 산점도로 데이터를 나타낼 수 있으므로
# 각 데이터의 관계성을 시각적으로 쉽게 이해할 수 있음
